# %% [markdown]
# # 03 · Supplier exploration

# %%
import pandas as pd
from pathlib import Path
p = Path('../data/exports/supplier_scorecard.csv')
print('Run the pipeline first' if not p.exists() else pd.read_csv(p).head())
